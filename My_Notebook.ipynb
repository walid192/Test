# %% [markdown]
# ## <strong>Walid Sboui</strong> <br/> Data Scientist

# %% [markdown]
# ## <h1> My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# ## I am interested in data science because it helps Solving complex problems.

# %% [markdown]
# ## Multiply two numbers

# %%
2*3
# Out:
# 6

# %% [markdown]
# <hr> <br> <ul>  why data science is interesting ?<li>Solving complex problems</li><li>Exploring vast amounts of data</li><li>Constant innovation and learning</li> </ul>
# <center><img src="data:image/jpeg;base64,..."/>
